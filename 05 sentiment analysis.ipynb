# %%
# !pip install SnowNLP
# Out:
# ...
#      |████████████████████████████████| 37.6 MB 5.9 MB/s eta 0:00:01    |███████                         | 8.2 MB 3.5 MB/s eta 0:00:09     |██████████████                  | 16.5 MB 3.3 MB/s eta 0:00:07     |██████████████████              | 21.2 MB 3.1 MB/s eta 0:00:06     |███████████████████████████▍    | 32.2 MB 4.0 MB/s eta 0:00:02     |████████████████████████████    | 32.9 MB 4.0 MB/s eta 0:00:02
# ...
#   Created wheel for SnowNLP: filename=snownlp-0.12.3-py3-none-any.whl size=37760956 sha256=84caad424c228974a4f124418a991dcf68ee2b14eca9a20b140c9575427e2c5a
#   Stored in directory: /Users/tsubomikaji/Library/Caches/pip/wheels/09/14/c5/ea9aee34229caa97c6f6ff78c82c7f2b1a3423c1f37227b6a6
# Successfully built SnowNLP
# ...

# %%
from snownlp import SnowNLP
import codecs
import os

# %%
#video 1 frequency of occurrence(danmaku)
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean1.txt','r',encoding = 'UTF-8')
line = source.readline()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print (s.sentiments)
    sentimentslist.append(s.sentiments)
import matplotlib.pyplot as plt
import numpy as np
plt.hist(sentimentslist, bins = np.arange(0, 1, 0.04), facecolor = 'g')
plt.xlabel('Sentiments Probability')
plt.ylabel('Quantity')
plt.title('Analysis of Sentiments - video1')
plt.show()
# Out:
# 0.5041975308641975
# 0.4726368159203981
# 0.5262327818078083
# 0.3950953678474117
# 0.5262327818078083

# %%
#analysis of sentiment distribution(danmaku)
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean1.txt','r',encoding = 'UTF-8')
line = source.readlines()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print(s.sentiments)
    sentimentslist.append(s.sentiments)

import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(0, 751, 1), sentimentslist, 'k-')
plt.xlabel('Time of Danmaku')
plt.ylabel('Sentiment')
plt.title('Analysis of Sentiments - video1')
plt.show()
# Out:
# 0.5689851767388825
# 0.4239541816561685
# 0.8838731328405868
# 0.31371089910834093
# 0.4774774774774775
# 0.855948838728563
# 0.8710051552184785
# 0.8041613747792647
# 0.4737672181921908
# 0.5262327818078083
# 0.4774774774774775
# 0.741250456187884
# 0.547227505792696
# 0.5689851767388825
# 0.6199902395182664
# 0.8726086049165379
# 0.6070326781070209
# 0.1745531551506878
# 0.7499999999999999
# 0.26388888888888906
# 0.7500624229391235
# 0.12031273220632144
# 0.5262327818078083
# 0.7809646276226134
# 0.6663463298769546
# 0.8838731328405868
# 0.8660111897946927
# 0.19365369029226398
# 0.8610832253759191
# 0.1450630707091416
# 0.2964271239924441
# 0.8109214345037912
# 0.410440278574139
# 0.5
# 0.31349209665953914
# 0.08375382479523108
# 0.18058059349554012
# 0.32721946539513314
# 0.5689851767388825
# 0.18473993422386847
# 0.3965027728122491
# 0.8486547378828734
# 0.8346656085644083
# 0.2086627918123508
# 0.7113145754302868
# 0.7486062971171528
# 0.8014264905309435
# 0.4913691286285672
# ...

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean2.txt','r',encoding = 'UTF-8')
line = source.readline()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print (s.sentiments)
    sentimentslist.append(s.sentiments)
import matplotlib.pyplot as plt
import numpy as np
plt.hist(sentimentslist, bins = np.arange(0, 1, 0.04), facecolor = 'g')
plt.xlabel('Sentiments Probability')
plt.ylabel('Quantity')
plt.title('Analysis of Sentiments - video2')
plt.show()
# Out:
# 0.42647058823529405
# 0.5882352941176473
# 0.2184873949579833
# 0.5962732919254661
# 0.5262327818078083
# 0.5604395604395602
# 0.3560057887120115
# 0.5262327818078083

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean2.txt','r',encoding = 'UTF-8')
line = source.readlines()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print(s.sentiments)
    sentimentslist.append(s.sentiments)

import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(0, 842, 1), sentimentslist, 'k-')
plt.xlabel('Time of Danmaku')
plt.ylabel('Sentiment')
plt.title('Analysis of Sentiments - video2')
plt.show()
# Out:
# 0.33048234722258196
# 0.8918114895900981
# 0.1837233963534416
# 0.6429335818357281
# 0.5299974686518168
# 0.4774774774774775
# 0.8292028852309892
# 0.022776114111071166
# 0.4406415033244223
# 0.13280896388599872
# 0.10706496577045366
# 0.31371089910834093
# 0.7376669139551424
# 0.21329544928724187
# 0.14754610322010686
# 0.6429335818357281
# 0.4285714285714284
# 0.8843949383042113
# 0.27209604401738574
# 0.38771787663040547
# 0.24915901559650544
# 0.5689851767388825
# 0.9519383122671627
# 0.7223261230587918
# 0.3924895598673752
# 0.8622431243278534
# 0.9496827014803813
# 0.8999999999999999
# 0.7987829937492171
# 0.16054628455788378
# 0.7951900005837058
# 0.4737672181921908
# 0.72443912986395
# 0.7598411334679942
# 0.5500691029384863
# 0.6119584955757301
# 0.9301331641754468
# 0.5111595570510141
# 0.7499999999999999
# 0.09319539375210839
# 0.1495074054114951
# 0.30240696771528286
# 0.5
# 0.5197943791213149
# 0.793978246363159
# 0.3148081920421206
# 0.28987485601080987
# ...

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean3.txt','r',encoding = 'UTF-8')
line = source.readline()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print (s.sentiments)
    sentimentslist.append(s.sentiments)
import matplotlib.pyplot as plt
import numpy as np
plt.hist(sentimentslist, bins = np.arange(0, 1, 0.04), facecolor = 'g')
plt.xlabel('Sentiments Probability')
plt.ylabel('Quantity')
plt.title('Analysis of Sentiments - video3')
plt.show()
# Out:
# 0.5262327818078083
# 0.8571428571428571
# 0.5262327818078083
# 0.6611570247933886
# 0.5983606557377048
# 0.5
# 0.5041975308641975
# 0.5262327818078083
# 0.5262327818078083

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean3.txt','r',encoding = 'UTF-8')
line = source.readlines()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print(s.sentiments)
    sentimentslist.append(s.sentiments)

import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(0, 420, 1), sentimentslist, 'k-')
plt.xlabel('Time of Danmaku')
plt.ylabel('Sentiment')
plt.title('Analysis of Sentiments - video3')
plt.show()
# Out:
# 0.28156585812521273
# 0.35691199845067245
# 0.1942410679028389
# 0.35593594891964075
# 0.31363797110573144
# 0.4913691286285672
# 0.41860465116279044
# 0.7499999999999999
# 0.0994247426731909
# 0.8088888888888889
# 0.39515974956431454
# 0.9925782453616708
# 0.5262327818078083
# 0.41860465116279044
# 0.1837233963534416
# 0.3142822120774551
# 0.125
# 0.8102074918281128
# 0.9773510495340744
# 0.3380469346624745
# 0.5277013134524622
# 0.16666666666666674
# 0.43337444185762064
# 0.39328332640132546
# 0.6395117809218285
# 0.2328180848821818
# 0.03843142829330637
# 0.5526162555454441
# 0.6838201032260187
# 0.6316739512502436
# 0.3846941923893873
# 0.6286844359887037
# 0.15138397084812327
# 0.5746308593108036
# 0.1037077781237149
# 0.7827650299794376
# 0.8692913340996072
# 0.8547850745169147
# 0.2358820269385239
# 0.09765188431041927
# 0.22968387460134843
# 0.4737672181921908
# 0.433500430309509
# 0.3558760240186444
# 0.6070326781070209
# 0.4475961338959168
# 0.48541419117631035
# ...

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean4.txt','r',encoding = 'UTF-8')
line = source.readline()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print (s.sentiments)
    sentimentslist.append(s.sentiments)
import matplotlib.pyplot as plt
import numpy as np
plt.hist(sentimentslist, bins = np.arange(0, 1, 0.04), facecolor = 'g')
plt.xlabel('Sentiments Probability')
plt.ylabel('Quantity')
plt.title('Analysis of Sentiments - video4')
plt.show()
# Out:
# 0.17699115044247804
# 0.7076023391812866
# 0.5262327818078083
# 0.5262327818078083
# 0.3684210526315791
# 0.6805555555555556
# 0.5262327818078083

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean4.txt','r',encoding = 'UTF-8')
line = source.readlines()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print(s.sentiments)
    sentimentslist.append(s.sentiments)

import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(0, 409, 1), sentimentslist, 'k-')
plt.xlabel('Time of danmaku')
plt.ylabel('Sentiment')
plt.title('Analysis of Sentiments - video4')
plt.show()
# Out:
# 0.4737672181921908
# 0.5490808966754104
# 0.41664169082868363
# 0.3205815415310954
# 0.48908842876422576
# 0.4737672181921908
# 0.17282336028167844
# 0.4980087632556971
# 0.2777777777777778
# 0.6000799053524202
# 0.18273753350365363
# 0.42000544271996154
# 0.5262327818078083
# 0.8490963719876924
# 0.624066844452473
# 0.10769937821878806
# 0.48783374468678053
# 0.4888472407346215
# 0.5167602727675337
# 0.5
# 0.4737672181921908
# 0.9264027315954378
# 0.054908620626548
# 0.8258342319512765
# 0.5
# 0.4737672181921908
# 0.5
# 0.8242386066176219
# 0.1837233963534416
# 0.6872260980949455
# 0.886484187055424
# 0.9453649235693312
# 0.8975315790311955
# 0.410440278574139
# 0.34790161820578314
# 0.7376669139551424
# 0.21031027791271284
# 0.7010254046924324
# 0.21119811891848939
# 0.8333333333333333
# 0.5724947050936575
# 0.34048049784196666
# 0.35593594891964075
# 0.624066844452473
# 0.670692320652986
# 0.3173320774757895
# 0.6558628208940429
# 0.5724947050936575
# 0.6729704765340161
# ...

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean5.txt','r',encoding = 'UTF-8')
line = source.readline()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print (s.sentiments)
    sentimentslist.append(s.sentiments)
import matplotlib.pyplot as plt
import numpy as np
plt.hist(sentimentslist, bins = np.arange(0, 1, 0.04), facecolor = 'g')
plt.xlabel('Sentiments Probability')
plt.ylabel('Quantity')
plt.title('Analysis of Sentiments - video5')
plt.show()
# Out:
# 0.5570776255707761
# 0.5262327818078083
# 0.9230769230769229
# 0.21739130434782616
# 0.634146341463415
# 0.5262327818078083
# 0.3593750000000002
# 0.5262327818078083

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Desktop/弹幕/清理data(2版/clean5.txt','r',encoding = 'UTF-8')
line = source.readlines()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print(s.sentiments)
    sentimentslist.append(s.sentiments)

import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(0, 920, 1), sentimentslist, 'k-')
plt.xlabel('Time of danmaku')
plt.ylabel('Sentiment')
plt.title('Analysis of Sentiments - video5')
plt.show()
# Out:
# 0.3398751854842078
# 0.856634625689578
# 0.9884431103746639
# 0.5705347296110681
# 0.6733320520021625
# 0.5439822525762399
# 0.3384490708848117
# 0.8404323777260825
# 0.6733320520021625
# 0.9884431103746639
# 0.8519199974934017
# 0.2836998458076392
# 0.9884431103746639
# 0.9884431103746639
# 0.9884431103746639
# 0.6733320520021625
# 0.8425529725829863
# 0.5306506111559446
# 0.5
# 0.44666010103906295
# 0.8437938897592069
# 0.5345446815381374
# 0.9000299615145505
# 0.6733320520021625
# 0.15060051578767286
# 0.4737672181921908
# 0.2818075546449774
# 0.5
# 0.9756819440429563
# 0.991357710394466
# 0.36734693877551017
# 0.5252509561603569
# 0.5262327818078083
# 0.34983848960806263
# 0.8088888888888889
# 0.7483050847457626
# 0.9539178902011254
# 0.08610002732053934
# 0.7674447764716916
# 0.6617643365225611
# 0.848527647015352
# 0.529577660440823
# 0.8308020896736894
# 0.39274798521627197
# 0.8632128723326787
# 0.848527647015352
# 0.5
# 0.5
# 0.5
# 0.3385004800575975
# 0.8333333333333333
# ...

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Downloads/dingdingcommentsclean5.txt','r',encoding = 'UTF-8')
line = source.readline()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print (s.sentiments)
    sentimentslist.append(s.sentiments)
import matplotlib.pyplot as plt
import numpy as np
plt.hist(sentimentslist, bins = np.arange(0, 1, 0.04), facecolor = 'g')
plt.xlabel('Sentiments Probability')
plt.ylabel('Quantity')
plt.title('Analysis of Sentiments - video5')
plt.show()
# Out:
# 0.5262327818078083
# 0.6081300813008129
# 0.5702515177797052
# 0.2777777777777778
# 0.2777777777777778
# 0.5875212430201505
# 0.5262327818078083
# 0.5262327818078083
# 0.4291609353507564
# 0.5262327818078083
# 0.5
# 0.5262327818078083
# 0.5262327818078083

# %%
from snownlp import SnowNLP
import codecs
import os

source = open('/Users/tsubomikaji/Downloads/dingdingcommentsclean5.txt','r',encoding = 'UTF-8')
line = source.readline()
sentimentslist = []
for i in line:
    s = SnowNLP(i.encode('UTF-8').decode('UTF-8'))
    print (s.sentiments)
    sentimentslist.append(s.sentiments)
import matplotlib.pyplot as plt
import numpy as np
plt.hist(sentimentslist, bins = np.arange(0, 1, 0.04), facecolor = 'g')
plt.xlabel('Sentiments Probability')
plt.ylabel('Quantity')
plt.title('Analysis of Sentiments - video5-comments')
plt.show()
# Out:
# 0.5262327818078083
# 0.6081300813008129
# 0.5702515177797052
# 0.2777777777777778
# 0.2777777777777778
# 0.5875212430201505
# 0.5262327818078083
# 0.5262327818078083
# 0.4291609353507564
# 0.5262327818078083
# 0.5
# 0.5262327818078083
# 0.5262327818078083
